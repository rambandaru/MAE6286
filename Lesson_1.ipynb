# %%
print ("Numerical Technical")
# Out:
# Numerical Technical

# %%
import numpy
import math
from scipy import integrate
from matplotlib import pyplot

# %%
# %matplotlib inline

# %%
N =  25
x_start, x_end = 0. , 5.0
y_start, y_end = 0. , 5.0
x = numpy.linspace (x_start, x_end, N)
y = numpy.linspace (y_start, y_end, N)

X, Y = numpy.meshgrid(x,y)

# %%
print ("X = ", x)
print ("Y = ", y)
# Out:
# X =  [ 0.          0.20833333  0.41666667  0.625       0.83333333  1.04166667
#   1.25        1.45833333  1.66666667  1.875       2.08333333  2.29166667
#   2.5         2.70833333  2.91666667  3.125       3.33333333  3.54166667
#   3.75        3.95833333  4.16666667  4.375       4.58333333  4.79166667
#   5.        ]
# Y =  [ 0.          0.20833333  0.41666667  0.625       0.83333333  1.04166667
#   1.25        1.45833333  1.66666667  1.875       2.08333333  2.29166667
#   2.5         2.70833333  2.91666667  3.125       3.33333333  3.54166667
#   3.75        3.95833333  4.16666667  4.375       4.58333333  4.79166667
#   5.        ]

# %%
size = 20
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))

pyplot.xlabel('x', fontsize = 16)
pyplot.ylabel('y', fontsize = 16)

pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)

pyplot.scatter(X, Y, s=10, color = 'green')
